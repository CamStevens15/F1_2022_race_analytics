# %%
# pulls modules from driver_comparison.py, which has all the functions for easy analysis of a race
from driver_comparisons import get_session, plot_driver_speed_change, get_driver_lap_comparison, fastest_lap_comparison, driver_gear_changes,  fastest_laptimes
import pandas as pd

# %%
#This calls on a specific session which telementry analysis can be perfromed on
spanish_quali = get_session(2022, "Spanish", "Q")
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v2.2.4]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '55', '63', '11', '44', '77', '20', '3', '47', '4', '31', '22', '10', '24', '5', '14', '18', '23', '6']

# %%
spanish_quali.laps.pick_fastest()
# Out:
# Time                      0 days 01:14:33.495000
# DriverNumber                                  16
# LapTime                   0 days 00:01:18.750000
# LapNumber                                     10
# Stint                                          4
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:22.004000
# Sector2Time               0 days 00:00:29.410000
# Sector3Time               0 days 00:00:27.336000
# Sector1SessionTime        0 days 01:13:36.749000
# Sector2SessionTime        0 days 01:14:06.159000
# Sector3SessionTime        0 days 01:14:33.495000
# SpeedI1                                    285.0
# SpeedI2                                    306.0
# SpeedFL                                    282.0
# SpeedST                                    316.0
# IsPersonalBest                              True
# Compound                                    SOFT
# ...

# %%
df_spanish_quali = pd.DataFrame(spanish_quali.laps)

# %%
df_spanish_quali.columns
# Out:
# Index(['Time', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime',
#        'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'LapStartTime', 'Team', 'Driver',
#        'TrackStatus', 'IsAccurate', 'LapStartDate'],
#       dtype='object')

# %%
fastest_laptimes(spanish_quali)
# Out:
# ['LEC' 'VER' 'SAI' 'RUS' 'PER' 'HAM' 'BOT' 'MAG' 'RIC' 'MSC' 'NOR' 'OCO'
#  'TSU' 'GAS' 'ZHO' 'VET' 'ALO' 'STR' 'ALB' 'LAT']

# %%
driver_gear_changes("LEC", spanish_quali)

# %%
plot_driver_speed_change("LEC", spanish_quali)

# %%
get_driver_lap_comparison("LEC","VER", spanish_quali)

# %%
spanish_race = get_session(2022, "Spanish", "R")
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v2.2.4]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '63', '55', '44', '77', '31', '4', '14', '22', '5', '3', '10', '47', '18', '6', '20', '23', '24', '16']

# %%
fastest_laptimes(spanish_race)
# Out:
# ['VER' 'PER' 'RUS' 'SAI' 'HAM' 'BOT' 'OCO' 'NOR' 'ALO' 'TSU' 'VET' 'RIC'
#  'GAS' 'MSC' 'STR' 'LAT' 'MAG' 'ALB' 'ZHO' 'LEC']

# %%
spanish_race.results
# Out:
#    DriverNumber BroadcastName Abbreviation         TeamName TeamColor  \
# 1             1  M VERSTAPPEN          VER  Red Bull Racing    1e5bc6
# 11           11       S PEREZ          PER  Red Bull Racing    1e5bc6
# 63           63     G RUSSELL          RUS         Mercedes    6cd3bf
# 55           55       C SAINZ          SAI          Ferrari    ed1c24
# 44           44    L HAMILTON          HAM         Mercedes    6cd3bf
# 77           77      V BOTTAS          BOT       Alfa Romeo    b12039
# 31           31        E OCON          OCO           Alpine    2293d1
# 4             4      L NORRIS          NOR          McLaren    f58020
# 14           14      F ALONSO          ALO           Alpine    2293d1
# 22           22     Y TSUNODA          TSU       AlphaTauri    4e7c9b
# 5             5      S VETTEL          VET     Aston Martin    2d826d
# 3             3   D RICCIARDO          RIC          McLaren    f58020
# ...

# %%
fastest_lap_comparison("HAM","ZHO", spanish_race)

# %%
plot_driver_speed_change("HAM", spanish_race)

# %%
plot_driver_speed_change("ZHO", spanish_race)

# %%
get_driver_lap_comparison("HAM","ZHO", spanish_race)
