# %%
from constructor_standings import ergast_retrieve, get_constructor_rankings

# %%
ergast_retrieve
# Out:
# <function constructor_standings.ergast_retrieve(api_endpoint: str)>

# %%
# This allows us to visualize championship points finish for round 11
get_constructor_rankings()

# %%
from driver_comparisons import get_session, driver_gear_changes, double_driver_lap_comparison, driver_speed_change, fastest_lap_comparison, fastest_laptimes

# %%
redbullring2022 = get_session(2022, "Austria", "Race")
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v2.2.4]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Finished loading data for 20 drivers: ['16', '1', '44', '63', '31', '47', '4', '20', '3', '14', '77', '23', '18', '24', '10', '22', '5', '55', '6', '11']

# %%
redbullring2022.laps.pick_driver("LEC")
# Out:
#                      Time DriverNumber                LapTime  LapNumber  \
# 0  0 days 01:03:27.742000           16                    NaT          1
# 1  0 days 01:04:38.351000           16 0 days 00:01:10.609000          2
# 2  0 days 01:05:48.279000           16 0 days 00:01:09.928000          3
# 3  0 days 01:06:58.417000           16 0 days 00:01:10.138000          4
# 4  0 days 01:08:08.685000           16 0 days 00:01:10.268000          5
# ..                    ...          ...                    ...        ...
# 66 0 days 02:22:02.733000           16 0 days 00:01:08.930000         67
# 67 0 days 02:23:11.704000           16 0 days 00:01:08.910000         68
# 68 0 days 02:24:20.284000           16 0 days 00:01:08.580000         69
# 69 0 days 02:25:29.117000           16 0 days 00:01:08.833000         70
# 70 0 days 02:26:38.466000           16 0 days 00:01:09.349000         71
#
#     Stint             PitOutTime PitInTime            Sector1Time  \
# ...

# %%
redbullring2022.laps.pick_fastest()
# Out:
# Time                      0 days 02:16:23.246000
# DriverNumber                                   1
# LapTime                   0 days 00:01:07.275000
# LapNumber                                     62
# Stint                                          4
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:17.144000
# Sector2Time               0 days 00:00:29.866000
# Sector3Time               0 days 00:00:20.265000
# Sector1SessionTime        0 days 02:15:33.115000
# Sector2SessionTime        0 days 02:16:02.981000
# Sector3SessionTime        0 days 02:16:23.246000
# SpeedI1                                    305.0
# SpeedI2                                    234.0
# SpeedFL                                    276.0
# SpeedST                                    312.0
# IsPersonalBest                              True
# Compound                                  MEDIUM
# ...

# %%
from static_plot import static_track_conditions, static_track_temp

# %%
fastest_laptimes(redbullring2022)
# Out:
# ['LEC' 'VER' 'HAM' 'RUS' 'OCO' 'MSC' 'NOR' 'MAG' 'RIC' 'ALO' 'BOT' 'ALB'
#  'STR' 'ZHO' 'GAS' 'TSU' 'VET' 'SAI' 'LAT' 'PER']

# %%
static_track_conditions(redbullring2022)

# %%
driver_gear_changes("VER", redbullring2022)

# %%
driver_gear_changes("LEC", redbullring2022)

# %%
driver_speed_change("VER", redbullring2022)

# %%
fastest_lap_comparison("VER", "LEC", redbullring2022)

# %%
double_driver_lap_comparison("VER", "LEC", redbullring2022)

# %%
double_driver_lap_comparison("LEC", "HAM", redbullring2022)

# %%
# This needs to be performed last, due to a bug in tis code that will mess up all the other imported plots

from F1_aws_plot import get_session, get_driver_aws_data

# %%
# This needs to be performed last, due to a bug in tis code that will mess up all the other imported plots
get_driver_aws_data("VER", "LEC", 1200, 2100, redbullring2022)

# %%
get_driver_aws_data("VER", "LEC", 3000, 4000, redbullring2022)
